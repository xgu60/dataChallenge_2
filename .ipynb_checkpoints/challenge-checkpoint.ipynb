# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv("data.csv")

# %%
data.shape
# Out:
# (1460, 43)

# %%
data.head()
# Out:
#    Unnamed: 0  X1  X2    X3     X4   X5  X6  X7    X8    X9   ...    X33  X34  \
# 0           0   1  60  65.0   8450  NaN   7   5  2003  2003   ...      0    0
# 1           1   2  20  80.0   9600  NaN   6   8  1976  1976   ...      0    0
# 2           2   3  60  68.0  11250  NaN   7   5  2001  2002   ...      0    0
# 3           3   4  70  60.0   9550  NaN   7   5  1915  1970   ...      0    0
# 4           4   5  60  84.0  14260  NaN   8   5  2000  2000   ...      0    0
#
#    X35  X36  X37  X38  X39  X40   X41     X42
# 0    0  NaN  NaN  NaN    0    2  2008  208500
# 1    0  NaN  NaN  NaN    0    5  2007  181500
# 2    0  NaN  NaN  NaN    0    9  2008  223500
# 3    0  NaN  NaN  NaN    0    2  2006  140000
# 4    0  NaN  NaN  NaN    0   12  2008  250000
#
# [5 rows x 43 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# X1               0
# X2               0
# X3             259
# X4               0
# X5            1369
# X6               0
# X7               0
# X8               0
# X9               0
# X10              8
# X11              0
# X12              0
# X13              0
# X14              0
# X15              0
# X16              0
# X17              0
# X18              0
# X19              0
# X20              0
# X21              0
# X22              0
# X23              0
# X24              0
# X25              0
# X26              0
# X27             81
# X28              0
# X29              0
# X30              0
# X31              0
# X32              0
# X33              0
# X34              0
# X35              0
# X36           1453
# X37           1179
# X38           1406
# X39              0
# X40              0
# X41              0
# X42              0
# dtype: int64

# %%
data = data.drop(columns=["X5", "X36", "X37", "X38"])

# %%
data.shape
# Out:
# (1460, 39)

# %%
discrete_columns = []
continuous_columns = []
for c in data.columns:
    unique_values = len(data.loc[:, c].unique())
    print (c, unique_values)
    if unique_values <= 10:
        discrete_columns.append(c)
    else:
        continuous_columns.append(c)
print(discrete_columns)
print(continuous_columns)
# Out:
# Unnamed: 0 1460
# X1 1460
# X2 15
# X3 111
# X4 1073
# X6 10
# X7 9
# X8 112
# X9 61
# X10 328
# X11 637
# X12 144
# X13 780
# X14 721
# X15 753
# X16 417
# X17 24
# X18 861
# X19 4
# X20 3
# X21 4
# X22 3
# X23 8
# X24 4
# X25 12
# X26 4
# X27 98
# X28 5
# X29 441
# X30 274
# X31 202
# X32 120
# X33 20
# X34 76
# X35 8
# X39 21
# X40 12
# X41 5
# X42 663
# ['X6', 'X7', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X26', 'X28', 'X35', 'X41']
# ['Unnamed: 0', 'X1', 'X2', 'X3', 'X4', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X25', 'X27', 'X29', 'X30', 'X31', 'X32', 'X33', 'X34', 'X39', 'X40', 'X42']

# %%
data.loc[:, discrete_columns].hist(bins=20, figsize=(16, 16));

# %%
fig, axes = plt.subplots(4, 3, figsize=(14, 20))
for i in range(12):
    data.boxplot("X42", by=discrete_columns[i], ax=axes[i//3, i%3]);

# %%
fig, axes = plt.subplots(6, 5, figsize=(20, 20))
for i in range(1, len(continuous_columns) - 1):
    data.plot.scatter(x=continuous_columns[i], y="X42", ax=axes[(i-1)//5, (i-1)%5]);

# %%
selected_columns = ["X" + str(i) for i in [6, 7, 21, 22, 26, 28, 3, 4, 10, 11, 14, 15, 16, 18, 25, 29, 42]]

# %%
selected_data = data.loc[:, selected_columns]

# %%
selected_data.shape
# Out:
# (1460, 17)

# %%
corr = selected_data.corr()
sns.heatmap(corr);

# %%
selected_data = selected_data.drop(columns=["X14", "X25", "X29"])

# %%
corr = selected_data.corr()
sns.heatmap(corr);
